# %%
import pandas as pd

df = pd.read_excel("southwark_survey_anonymised.xlsx")  
df.head()
# Out:
#   How long have you been involved in the garden project? - how long - Less than a year  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                   Less than a year
# 4                                                NaN
#
#   How long have you been involved in the garden project? - how long - 1-2 years  \
# 0                                                NaN
# 1                                          1-2 years
# 2                                                NaN
# 3                                                NaN
# 4                                          1-2 years
#
#   How long have you been involved in the garden project? - how long - 3-5 years  \
# 0                                                NaN
# 1                                                NaN
# 2                                          3-5 years
# ...

# %%
df.columns
# Out:
# Index(['How long have you been involved in the garden project? - how long - Less than a year',
#        'How long have you been involved in the garden project? - how long - 1-2 years',
#        'How long have you been involved in the garden project? - how long - 3-5 years',
#        'How long have you been involved in the garden project? - how long - Over 5 years',
#        'How long have you been involved in the garden project? - how long - I am not involved in the garden project',
#        'Are you involved in coordinating your garden group? - coordinating',
#        'Has your group applied for a grant since your site started? - grant application',
#        'Has your group applied for a grant since your site started? - If yes, please enter details, if known:',
#        'How often does your group meet? For example for a training session or communal workdays. - meeting frequency',
# ...

# %%
df.drop(columns=['Visited Pages - Introduction',
       'Visited Pages - Group section (please only complete if you are coordinating your gardening group).',
       'Visited Pages - Health and Wellbeing', 'Visited Pages - Community',
       'Visited Pages - Economic Impacts', 'Visited Pages - General comments',
       'Visited Pages - About you'], inplace=True, errors="ignore")
